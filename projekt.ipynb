# %%
import pandas as pd
df = pd.read_csv('messy_data.csv')

# %%
df
# Out:
#      carat  clarity  color         cut  x dimension  y dimension  z dimension  \
# 0     0.50       IF      D       Ideal          5.1         5.15          3.2
# 1     0.70     vvs2      E     premium          5.7                      3.52
# 2      NaN      Si2      h        Good          4.3         4.31
# 3     1.20       if      d       ideal                      6.82          4.2
# 4     0.90       I1      J        Fair            6                       3.7
# ..     ...      ...    ...         ...          ...          ...          ...
# 195   0.45      si1      F   very good          4.9         4.89
# 196   1.25     VVS2      H        Good          6.9                      4.27
# 197   0.55       i1      I     Premium          5.3                      3.28
# 198   0.85      Si2      E        fair          6.1         6.13         3.78
# 199    NaN     VVS1      G   Very good          6.4         6.43         3.97
#
#      depth  table    price
# 0     61.5            3000
# 1       62     59     4500
# 2     62.3     56      700
# 3     61.7     58    10000
# 4     61.7            2400
# ..     ...    ...      ...
# 195   62.4     59     2300
# 196            55    10400
# 197   62.3     57   150000
# 198            58     6300
# 199   62.5            7500
#
# [200 rows x 10 columns]

# %%
# a. Usunięcie duplikatów
df = df.drop_duplicates()
df
# Out:
#      carat  clarity  color         cut  x dimension  y dimension  z dimension  \
# 0     0.50       IF      D       Ideal          5.1         5.15          3.2
# 1     0.70     vvs2      E     premium          5.7                      3.52
# 2      NaN      Si2      h        Good          4.3         4.31
# 3     1.20       if      d       ideal                      6.82          4.2
# 4     0.90       I1      J        Fair            6                       3.7
# ..     ...      ...    ...         ...          ...          ...          ...
# 195   0.45      si1      F   very good          4.9         4.89
# 196   1.25     VVS2      H        Good          6.9                      4.27
# 197   0.55       i1      I     Premium          5.3                      3.28
# 198   0.85      Si2      E        fair          6.1         6.13         3.78
# 199    NaN     VVS1      G   Very good          6.4         6.43         3.97
#
#      depth  table    price
# 0     61.5            3000
# 1       62     59     4500
# 2     62.3     56      700
# 3     61.7     58    10000
# 4     61.7            2400
# ..     ...    ...      ...
# 195   62.4     59     2300
# 196            55    10400
# 197   62.3     57   150000
# 198            58     6300
# 199   62.5            7500
#
# [200 rows x 10 columns]

# %%
df = df.dropna()
df
# Out:
#      carat  clarity  color         cut  x dimension  y dimension  z dimension  \
# 0     0.50       IF      D       Ideal          5.1         5.15          3.2
# 1     0.70     vvs2      E     premium          5.7                      3.52
# 3     1.20       if      d       ideal                      6.82          4.2
# 4     0.90       I1      J        Fair            6                       3.7
# 6     0.50       if      D       Ideal          5.1                       3.2
# ..     ...      ...    ...         ...          ...          ...          ...
# 194   0.95      Si1      G       Ideal          6.4         6.42         3.96
# 195   0.45      si1      F   very good          4.9         4.89
# 196   1.25     VVS2      H        Good          6.9                      4.27
# 197   0.55       i1      I     Premium          5.3                      3.28
# 198   0.85      Si2      E        fair          6.1         6.13         3.78
#
#      depth  table    price
# 0     61.5            3000
# 1       62     59     4500
# 3     61.7     58    10000
# 4     61.7            2400
# 6     61.5     57     3100
# ..     ...    ...      ...
# 194            56     7100
# 195   62.4     59     2300
# 196            55    10400
# 197   62.3     57   150000
# 198            58     6300
#
# [150 rows x 10 columns]

# %%
df.info()
df.columns = df.columns.str.strip()
numeric_columns = ['x dimension', 'y dimension', 'z dimension', 'depth', 'price', 'table']
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')
df['clarity'] = df['clarity'].astype("string")
df['clarity'] = df['clarity'].str.upper()
df['color'] = df['color'].astype("string")
df['cut'] = df['cut'].astype("string")
df['cut'] = df['cut'].str.upper()
df = df.dropna(axis=0, subset=['x dimension', 'y dimension', 'z dimension', 'depth', 'price'])
df['price'] = df['price'].astype("int64")
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150 entries, 0 to 198
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   carat         150 non-null    float64
#  1    clarity      150 non-null    object
#  2    color        150 non-null    object
#  3    cut          150 non-null    object
#  4    x dimension  150 non-null    object
#  5    y dimension  150 non-null    object
#  6    z dimension  150 non-null    object
#  7    depth        150 non-null    object
#  8    table        150 non-null    object
#  9    price        150 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 12.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 22 entries, 0 to 191
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   carat        22 non-null     float64
#  1   clarity      22 non-null     string
#  2   color        22 non-null     string
#  3   cut          22 non-null     string
#  4   x dimension  22 non-null     float64
#  5   y dimension  22 non-null     float64
#  6   z dimension  22 non-null     float64
#  7   depth        22 non-null     float64
#  8   table        5 non-null      float64
#  9   price        22 non-null     int64
# dtypes: float64(6), int64(1), string(3)
# memory usage: 1.9 KB
# /var/folders/zj/cckyfy1j6d3g0tg4gytb4wtm0000gn/T/ipykernel_83877/951000060.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')
# /var/folders/zj/cckyfy1j6d3g0tg4gytb4wtm0000gn/T/ipykernel_83877/951000060.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['clarity'] = df['clarity'].astype("string")
# /var/folders/zj/cckyfy1j6d3g0tg4gytb4wtm0000gn/T/ipykernel_83877/951000060.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['clarity'] = df['clarity'].str.upper()
# /var/folders/zj/cckyfy1j6d3g0tg4gytb4wtm0000gn/T/ipykernel_83877/951000060.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['color'] = df['color'].astype("string")
# /var/folders/zj/cckyfy1j6d3g0tg4gytb4wtm0000gn/T/ipykernel_83877/951000060.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cut'] = df['cut'].astype("string")
# /var/folders/zj/cckyfy1j6d3g0tg4gytb4wtm0000gn/T/ipykernel_83877/951000060.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cut'] = df['cut'].str.upper()
# /var/folders/zj/cckyfy1j6d3g0tg4gytb4wtm0000gn/T/ipykernel_83877/951000060.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'] = df['price'].astype("int64")
#      carat clarity       color         cut  x dimension  y dimension  \
# 0     0.50      IF           D       IDEAL          5.1         5.15
# 25    0.20     SI1           H   VERY GOOD          3.9         3.89
# 28    0.55      I1           j     PREMIUM          5.4         5.42
# 32    0.90     SI2           h        FAIR          6.1         6.12
# 40    0.45     SI2           H       IDEAL          4.8         4.82
# 43    0.95    VVS2           D        GOOD          6.3         6.31
# 50    0.65     SI1   Colorless   VERY GOOD          5.6         5.58
# 56    0.40     SI1           j   VERY GOOD          4.8         4.78
# 62    0.35      I1           G       IDEAL          4.5         4.52
# 66    0.40    VVS2           j        GOOD          4.7         4.69
# 69    0.70     SI2           d        GOOD          5.7         5.69
# 88    1.15    VVS2           H        FAIR          6.7         6.71
# 90    0.70     SI1           I     PREMIUM          5.7         5.68
# 96    0.75     SI1           I   VERY GOOD          5.9         5.88
# 106   1.15     SI1           G   VERY GOOD          6.8         6.82
# 108   0.70     SI2           H       IDEAL          5.7         5.68
# 128   0.55     SI1           I        FAIR          5.4         5.39
# 135   1.05    VVS2           e       IDEAL          6.6         6.62
# 154   1.20     SI2           F     PREMIUM          6.9         6.88
# 159   0.75     SI1           F     PREMIUM          5.9         5.91
# 179   1.20      I1           G     PREMIUM          6.8         6.81
# 191   1.15    VVS1           G     PREMIUM          6.8         6.85
#
#      z dimension  depth  table  price
# 0           3.20   61.5    NaN   3000
# 25          2.41   62.1    NaN    500
# 28          3.35   62.1    NaN   2500
# 32          3.78   62.4    NaN   2600
# 40          3.01   62.1   56.0   1500
# 43          3.91   62.4    NaN   7300
# 50          3.48   62.6    NaN   3300
# 56          2.96   62.2    NaN   1400
# 62          2.79   62.0    NaN    900
# 66          2.91   62.1    NaN   1800
# 69          3.53   62.5    NaN   4000
# 88          4.14   62.6    NaN   9200
# 90          3.53   62.7   58.0   4100
# 96          3.65   62.3    NaN   4400
# 106         4.21   62.6   58.0   9300
# 108         3.52   62.5    NaN   4200
# 128         3.33   62.6    NaN   2800
# 135         4.09   62.6    NaN   9300
# 154         4.27   62.5   56.0  10100
# 159         3.66   62.3   59.0   4600
# 179         4.21   62.7    NaN  10100
# 191         4.23   62.7    NaN   9800

# %%
df = df.drop('table', axis=1)
df
# Out:
#      carat clarity       color         cut  x dimension  y dimension  \
# 0     0.50      IF           D       IDEAL          5.1         5.15
# 25    0.20     SI1           H   VERY GOOD          3.9         3.89
# 28    0.55      I1           j     PREMIUM          5.4         5.42
# 32    0.90     SI2           h        FAIR          6.1         6.12
# 40    0.45     SI2           H       IDEAL          4.8         4.82
# 43    0.95    VVS2           D        GOOD          6.3         6.31
# 50    0.65     SI1   Colorless   VERY GOOD          5.6         5.58
# 56    0.40     SI1           j   VERY GOOD          4.8         4.78
# 62    0.35      I1           G       IDEAL          4.5         4.52
# 66    0.40    VVS2           j        GOOD          4.7         4.69
# 69    0.70     SI2           d        GOOD          5.7         5.69
# 88    1.15    VVS2           H        FAIR          6.7         6.71
# 90    0.70     SI1           I     PREMIUM          5.7         5.68
# 96    0.75     SI1           I   VERY GOOD          5.9         5.88
# 106   1.15     SI1           G   VERY GOOD          6.8         6.82
# 108   0.70     SI2           H       IDEAL          5.7         5.68
# 128   0.55     SI1           I        FAIR          5.4         5.39
# 135   1.05    VVS2           e       IDEAL          6.6         6.62
# 154   1.20     SI2           F     PREMIUM          6.9         6.88
# 159   0.75     SI1           F     PREMIUM          5.9         5.91
# 179   1.20      I1           G     PREMIUM          6.8         6.81
# 191   1.15    VVS1           G     PREMIUM          6.8         6.85
#
#      z dimension  depth  price
# 0           3.20   61.5   3000
# 25          2.41   62.1    500
# 28          3.35   62.1   2500
# 32          3.78   62.4   2600
# 40          3.01   62.1   1500
# 43          3.91   62.4   7300
# 50          3.48   62.6   3300
# 56          2.96   62.2   1400
# 62          2.79   62.0    900
# 66          2.91   62.1   1800
# 69          3.53   62.5   4000
# 88          4.14   62.6   9200
# 90          3.53   62.7   4100
# 96          3.65   62.3   4400
# 106         4.21   62.6   9300
# 108         3.52   62.5   4200
# 128         3.33   62.6   2800
# 135         4.09   62.6   9300
# 154         4.27   62.5  10100
# 159         3.66   62.3   4600
# 179         4.21   62.7  10100
# 191         4.23   62.7   9800

# %%
# wartosci odstajace na carat
q_low = df["carat"].quantile(0.01)
q_hi  = df["carat"].quantile(0.99)
print(q_low)
print(q_hi)
df = df[(df["carat"] < q_hi) & (df["carat"] > q_low)]
df
# Out:
# 0.2315
# 1.2
#      carat clarity       color         cut  x dimension  y dimension  \
# 0     0.50      IF           D       IDEAL          5.1         5.15
# 28    0.55      I1           j     PREMIUM          5.4         5.42
# 32    0.90     SI2           h        FAIR          6.1         6.12
# 40    0.45     SI2           H       IDEAL          4.8         4.82
# 43    0.95    VVS2           D        GOOD          6.3         6.31
# 50    0.65     SI1   Colorless   VERY GOOD          5.6         5.58
# 56    0.40     SI1           j   VERY GOOD          4.8         4.78
# 62    0.35      I1           G       IDEAL          4.5         4.52
# 66    0.40    VVS2           j        GOOD          4.7         4.69
# 69    0.70     SI2           d        GOOD          5.7         5.69
# 88    1.15    VVS2           H        FAIR          6.7         6.71
# 90    0.70     SI1           I     PREMIUM          5.7         5.68
# 96    0.75     SI1           I   VERY GOOD          5.9         5.88
# 106   1.15     SI1           G   VERY GOOD          6.8         6.82
# 108   0.70     SI2           H       IDEAL          5.7         5.68
# 128   0.55     SI1           I        FAIR          5.4         5.39
# 135   1.05    VVS2           e       IDEAL          6.6         6.62
# 159   0.75     SI1           F     PREMIUM          5.9         5.91
# 191   1.15    VVS1           G     PREMIUM          6.8         6.85
#
#      z dimension  depth  price
# 0           3.20   61.5   3000
# 28          3.35   62.1   2500
# 32          3.78   62.4   2600
# 40          3.01   62.1   1500
# 43          3.91   62.4   7300
# 50          3.48   62.6   3300
# 56          2.96   62.2   1400
# 62          2.79   62.0    900
# 66          2.91   62.1   1800
# 69          3.53   62.5   4000
# 88          4.14   62.6   9200
# 90          3.53   62.7   4100
# 96          3.65   62.3   4400
# 106         4.21   62.6   9300
# 108         3.52   62.5   4200
# 128         3.33   62.6   2800
# 135         4.09   62.6   9300
# 159         3.66   62.3   4600
# 191         4.23   62.7   9800

# %%
#kolumna cut jako categorical
df['cut'] = df.cut.astype('category')
df['cut'].describe()
# Out:
# /var/folders/zj/cckyfy1j6d3g0tg4gytb4wtm0000gn/T/ipykernel_83877/3853331942.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cut'] = df.cut.astype('category')
# count         19
# unique         5
# top        IDEAL
# freq           5
# Name: cut, dtype: object

# %%
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19 entries, 0 to 191
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   carat        19 non-null     float64
#  1   clarity      19 non-null     string
#  2   color        19 non-null     string
#  3   cut          19 non-null     category
#  4   x dimension  19 non-null     float64
#  5   y dimension  19 non-null     float64
#  6   z dimension  19 non-null     float64
#  7   depth        19 non-null     float64
#  8   price        19 non-null     int64
# dtypes: category(1), float64(5), int64(1), string(2)
# memory usage: 1.6 KB
#      carat clarity       color         cut  x dimension  y dimension  \
# 0     0.50      IF           D       IDEAL          5.1         5.15
# 28    0.55      I1           j     PREMIUM          5.4         5.42
# 32    0.90     SI2           h        FAIR          6.1         6.12
# 40    0.45     SI2           H       IDEAL          4.8         4.82
# 43    0.95    VVS2           D        GOOD          6.3         6.31
# 50    0.65     SI1   Colorless   VERY GOOD          5.6         5.58
# 56    0.40     SI1           j   VERY GOOD          4.8         4.78
# 62    0.35      I1           G       IDEAL          4.5         4.52
# 66    0.40    VVS2           j        GOOD          4.7         4.69
# 69    0.70     SI2           d        GOOD          5.7         5.69
# 88    1.15    VVS2           H        FAIR          6.7         6.71
# 90    0.70     SI1           I     PREMIUM          5.7         5.68
# 96    0.75     SI1           I   VERY GOOD          5.9         5.88
# 106   1.15     SI1           G   VERY GOOD          6.8         6.82
# 108   0.70     SI2           H       IDEAL          5.7         5.68
# 128   0.55     SI1           I        FAIR          5.4         5.39
# 135   1.05    VVS2           e       IDEAL          6.6         6.62
# 159   0.75     SI1           F     PREMIUM          5.9         5.91
# 191   1.15    VVS1           G     PREMIUM          6.8         6.85
#
#      z dimension  depth  price
# 0           3.20   61.5   3000
# 28          3.35   62.1   2500
# 32          3.78   62.4   2600
# 40          3.01   62.1   1500
# 43          3.91   62.4   7300
# 50          3.48   62.6   3300
# 56          2.96   62.2   1400
# 62          2.79   62.0    900
# 66          2.91   62.1   1800
# 69          3.53   62.5   4000
# 88          4.14   62.6   9200
# 90          3.53   62.7   4100
# 96          3.65   62.3   4400
# 106         4.21   62.6   9300
# 108         3.52   62.5   4200
# 128         3.33   62.6   2800
# 135         4.09   62.6   9300
# 159         3.66   62.3   4600
# 191         4.23   62.7   9800
